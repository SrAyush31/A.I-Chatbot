# %% [markdown]
# <a href="https://colab.research.google.com/github/SrAyush31/A.I-Chatbot/blob/main/ChatBot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib
matplotlib.use('Agg')
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle
# %matplotlib inline

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents.json').read()
intents = json.loads(data_file)


for intent in intents['intents']:
    for pattern in intent['patterns']:

        # take each word and tokenize it
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        # adding documents
        documents.append((w, intent['tag']))

        # adding classes to our class list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

classes = sorted(list(set(classes)))

print (len(documents), "documents")

print (len(classes), "classes", classes)
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']

# %%
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# initializing training data
training = []
output_empty = [0] * len(classes)
for doc in documents:
    # initializing bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/200
# 10/10 [==============================] - 12s 3ms/step - loss: 2.2145 - accuracy: 0.1283
# Epoch 2/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.1133 - accuracy: 0.1576
# Epoch 3/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.1162 - accuracy: 0.2869
# Epoch 4/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.9083 - accuracy: 0.4105
# Epoch 5/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.9235 - accuracy: 0.3429
# Epoch 6/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.8829 - accuracy: 0.2685
# Epoch 7/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.7247 - accuracy: 0.4382
# Epoch 8/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.5325 - accuracy: 0.6157
# Epoch 9/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3565 - accuracy: 0.7154
# Epoch 10/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.4234 - accuracy: 0.5437
# Epoch 11/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1128 - accuracy: 0.7213
# Epoch 12/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2413 - accuracy: 0.6154
# Epoch 13/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9054 - accuracy: 0.7708
# Epoch 14/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8798 - accuracy: 0.8808
# Epoch 15/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.7692 - accuracy: 0.8391
# Epoch 16/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7102 - accuracy: 0.7643
# Epoch 17/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7457 - accuracy: 0.8765
# Epoch 18/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6471 - accuracy: 0.8333
# Epoch 19/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5561 - accuracy: 0.8552
# Epoch 20/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6334 - accuracy: 0.8697
# Epoch 21/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6035 - accuracy: 0.7717
# Epoch 22/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3312 - accuracy: 0.9114
# Epoch 23/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.7213 - accuracy: 0.7148
# Epoch 24/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5103 - accuracy: 0.8894
# Epoch 25/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4134 - accuracy: 0.8733
# Epoch 26/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3309 - accuracy: 0.8451
# Epoch 27/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3968 - accuracy: 0.8436
# Epoch 28/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1953 - accuracy: 0.9491
# Epoch 29/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2211 - accuracy: 0.9578
# Epoch 30/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2533 - accuracy: 0.9661
# Epoch 31/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3504 - accuracy: 0.9142
# Epoch 32/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2697 - accuracy: 0.8408
# Epoch 33/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2927 - accuracy: 0.8500
# Epoch 34/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1406 - accuracy: 0.9673
# Epoch 35/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0964 - accuracy: 1.0000
# Epoch 36/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2906 - accuracy: 0.9629
# Epoch 37/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1277 - accuracy: 0.9941
# Epoch 38/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1081 - accuracy: 1.0000
# Epoch 39/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1862 - accuracy: 0.9748
# Epoch 40/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1832 - accuracy: 0.9553
# Epoch 41/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1523 - accuracy: 0.9339
# Epoch 42/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2780 - accuracy: 0.8992
# Epoch 43/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1564 - accuracy: 0.9547
# Epoch 44/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1587 - accuracy: 0.9918
# Epoch 45/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1197 - accuracy: 0.9660
# Epoch 46/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1613 - accuracy: 0.9485
# Epoch 47/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1418 - accuracy: 0.9388
# Epoch 48/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1185 - accuracy: 0.9780
# Epoch 49/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0824 - accuracy: 0.9918
# Epoch 50/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0712 - accuracy: 1.0000
# Epoch 51/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0585 - accuracy: 1.0000
# Epoch 52/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1106 - accuracy: 0.9720
# Epoch 53/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1260 - accuracy: 1.0000
# Epoch 54/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0781 - accuracy: 0.9892
# Epoch 55/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0804 - accuracy: 1.0000
# Epoch 56/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0458 - accuracy: 0.9892
# Epoch 57/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0904 - accuracy: 0.9629
# Epoch 58/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2170 - accuracy: 0.8894
# Epoch 59/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1081 - accuracy: 0.9780
# Epoch 60/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0823 - accuracy: 0.9803
# Epoch 61/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1146 - accuracy: 0.9447
# Epoch 62/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0999 - accuracy: 0.9780
# Epoch 63/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0485 - accuracy: 1.0000
# Epoch 64/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0370 - accuracy: 1.0000
# Epoch 65/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0619 - accuracy: 1.0000
# Epoch 66/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0433 - accuracy: 1.0000
# Epoch 67/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0408 - accuracy: 1.0000
# Epoch 68/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0516 - accuracy: 1.0000
# Epoch 69/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0809 - accuracy: 0.9720
# Epoch 70/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 71/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0906 - accuracy: 0.9720
# Epoch 72/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0359 - accuracy: 1.0000
# Epoch 73/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0584 - accuracy: 1.0000
# Epoch 74/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0490 - accuracy: 1.0000
# Epoch 75/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0929 - accuracy: 0.9582
# Epoch 76/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1326 - accuracy: 0.9826
# Epoch 77/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0423 - accuracy: 1.0000
# Epoch 78/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 79/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0288 - accuracy: 0.9961
# Epoch 80/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1268 - accuracy: 0.9409
# Epoch 81/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0353 - accuracy: 1.0000
# Epoch 82/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0798 - accuracy: 0.9447
# Epoch 83/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 84/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0406 - accuracy: 0.9780
# Epoch 85/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0574 - accuracy: 0.9961
# Epoch 86/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0293 - accuracy: 1.0000
# Epoch 87/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0865 - accuracy: 1.0000
# Epoch 88/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0500 - accuracy: 0.9941
# Epoch 89/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0458 - accuracy: 0.9892
# Epoch 90/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0274 - accuracy: 1.0000
# Epoch 91/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0441 - accuracy: 1.0000
# Epoch 92/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 0.9629
# Epoch 93/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0260 - accuracy: 1.0000
# Epoch 94/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 95/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0387 - accuracy: 0.9918
# Epoch 96/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0765 - accuracy: 0.9545
# Epoch 97/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0490 - accuracy: 0.9720
# Epoch 98/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0220 - accuracy: 0.9892
# Epoch 99/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0338 - accuracy: 0.9961
# Epoch 100/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0721 - accuracy: 1.0000
# Epoch 101/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0667 - accuracy: 0.9721
# Epoch 102/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1250 - accuracy: 0.9447
# Epoch 103/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 104/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0330 - accuracy: 0.9961
# Epoch 105/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0357 - accuracy: 1.0000
# Epoch 106/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0406 - accuracy: 1.0000
# Epoch 107/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0729 - accuracy: 0.9447
# Epoch 108/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 109/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 110/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0651 - accuracy: 0.9447
# Epoch 111/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1101 - accuracy: 0.9447
# Epoch 112/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 113/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0327 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0336 - accuracy: 1.0000
# Epoch 115/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1166 - accuracy: 0.9681
# Epoch 116/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0502 - accuracy: 1.0000
# Epoch 117/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0222 - accuracy: 0.9941
# Epoch 118/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0565 - accuracy: 1.0000
# Epoch 119/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0316 - accuracy: 1.0000
# Epoch 120/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 121/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 122/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0412 - accuracy: 0.9826
# Epoch 123/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 124/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0278 - accuracy: 0.9961
# Epoch 125/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0316 - accuracy: 1.0000
# Epoch 126/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0501 - accuracy: 1.0000
# Epoch 127/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0414 - accuracy: 1.0000
# Epoch 128/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0242 - accuracy: 1.0000
# Epoch 129/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0388 - accuracy: 0.9582
# Epoch 130/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 131/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0257 - accuracy: 1.0000
# Epoch 132/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 133/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0782 - accuracy: 0.9521
# Epoch 134/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 135/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0323 - accuracy: 1.0000
# Epoch 137/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1917 - accuracy: 0.9076
# Epoch 138/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 139/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0428 - accuracy: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0649 - accuracy: 0.9826
# Epoch 141/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0476 - accuracy: 0.9918
# Epoch 142/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 143/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 144/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0259 - accuracy: 1.0000
# Epoch 145/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0458 - accuracy: 1.0000
# Epoch 146/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0268 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0381 - accuracy: 1.0000
# Epoch 148/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 149/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 0.9862
# Epoch 150/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0957 - accuracy: 0.9629
# Epoch 151/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0262 - accuracy: 1.0000
# Epoch 153/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 154/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0523 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 156/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 157/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 158/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0700 - accuracy: 0.9447
# Epoch 160/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0375 - accuracy: 1.0000
# Epoch 161/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0197 - accuracy: 0.9811
# Epoch 162/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 0.9629
# Epoch 163/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 165/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0262 - accuracy: 0.9892
# Epoch 167/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 169/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0239 - accuracy: 1.0000
# Epoch 170/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0236 - accuracy: 1.0000
# Epoch 172/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 173/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 174/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0220 - accuracy: 0.9918
# Epoch 175/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 176/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0334 - accuracy: 1.0000
# Epoch 177/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0191 - accuracy: 0.9918
# Epoch 178/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 179/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 180/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0250 - accuracy: 0.9918
# Epoch 181/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0612 - accuracy: 0.9720
# Epoch 182/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0491 - accuracy: 0.9629
# Epoch 185/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 186/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 187/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0524 - accuracy: 1.0000
# Epoch 188/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 189/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 193/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0677 - accuracy: 0.9629
# Epoch 195/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0265 - accuracy: 0.9892
# Epoch 197/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1063 - accuracy: 0.9227
# Epoch 198/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0205 - accuracy: 0.9862
# Epoch 199/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0104 - accuracy: 1.0000
# model created

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np

from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))
model = load_model('chatbot_model.h5')

# %%
def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s:
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

while True:
  message = input('')
  ints = predict_class(message,model)
  res = getResponse(ints, intents)
  print(res)
# Out:
# hello
# Hi there, how can I help?
#
# Hi there, how can I help?
#
# Good to see you again
#
# Hello, thanks for asking
# what can you do
# I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
# hospitals
# Please provide hospital name or location
#
# Hello, thanks for asking
# bye
# See you!

# %%
### CREATE VIRTUAL DISPLAY ###
# !apt-get install -y xvfb # Install X Virtual Frame Buffer
import os
os.system('Xvfb :1 -screen 0 1600x1200x16  &')    # create virtual display with size 1600x1200 and 16 bit color. Color can be changed to 24 or 8
os.environ['DISPLAY']=':1.0'

# %%
def chatbot_response(msg):
    ints = predict_class(msg, model)
    res = getResponse(ints, intents)
    return res
